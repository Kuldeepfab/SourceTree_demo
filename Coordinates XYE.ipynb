# %%
#Adding Cooments in Branch_01.

# %%
# again adding dummy comments in branch01

# %%
# Creating Txt File consisting X Y and E in forward and revered direction.
import math
import numpy as np
from math import *
radius=int(input("Enter the Radius:"))
Angle=int(input("Enter the Angle in Degree: "))
step=Angle
Angle_radian=math.radians(Angle)
theta = np.linspace( 0 , Angle_radian , step )
x = radius * np.cos( theta ) 
y = radius * np.sin( theta )
alpha=0
f = open("coordinates.txt", "a")
f.write("\n")
f.write(";START")
f.close
for i in range(0,step):
    if alpha<1: # for second coorinates to add the distance side of the cooridnates
        f = open("coordinates.txt", "a")
        f.write("\n")
        f.write("G1 X {:.2f} Y {:.2f}".format(x[i],y[i]))
        f.close
        alpha+=1
    else:
        distance=sqrt((x[i]-x[i-1])**2 + (y[i]-y[i-1])**2) # calculating distance between two coordinates (x1,y1) and (x2,y2)
        f = open("coordinates.txt", "a")
        f.write("\n")
        f.write("G1 X {:.2f} Y {:.2f} E {:.2f}".format(x[i],y[i],distance))
        f.close    
f = open("coordinates.txt", "a")
f.write("\n")
f.write(";REVERSE")
f.close
beta=0
for j in range(step-1,-1,-1): # for revere points
    if beta<1: 
        f = open("coordinates.txt", "a")
        f.write("\n")    
        f.write("G1 X {:.2f} Y {:.2f}".format(x[j],y[j]))
        f.close
        beta+=1
    else:
        distance=sqrt((x[j]-x[j+1])**2 + (y[j]-y[j+1])**2)
        f = open("coordinates.txt", "a")
        f.write("\n") 
        f.write("G1 X {:.2f} Y {:.2f} E {:.2f}".format(x[j],y[j],distance)) 
        f.close
f = open("coordinates.txt", "a")
f.write("\n")
f.close()  
#If want to see the circle ( for visualization) 
#figure, axes = plt.subplots( 1 ) 
#axes.plot( x, y ) 
#axes.set_aspect( 1 ) 

# Sucessfully added in forward and reversed list.
# Out:
# Enter the Radius:15
# Enter the Angle in Degree: 120

# %%
# Integrating Z adding concept and printing only.

# %%
# Out:
# Enter the Radius:5
# Enter the Angle in Degree 10
# Enter the last value of Z you want.3
# ;START
# G1 F600 Z0.20
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z0.40
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z0.60
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z0.80
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z1.00
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z1.20
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z1.40
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z1.60
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z1.80
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z2.00
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z2.20
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z2.40
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10
# ;START
# G1 F600 Z2.60
# X 5.00 Y 0.00
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.94 Y 0.77 E 0.10
# X 4.92 Y 0.87 E 0.10
# ;REVERSE
# G1 F600 Z2.80
# X 4.92 Y 0.87
# X 4.94 Y 0.77 E 0.10
# X 4.95 Y 0.68 E 0.10
# X 4.97 Y 0.58 E 0.10
# X 4.98 Y 0.48 E 0.10
# X 4.98 Y 0.39 E 0.10
# X 4.99 Y 0.29 E 0.10
# X 5.00 Y 0.19 E 0.10
# X 5.00 Y 0.10 E 0.10
# X 5.00 Y 0.00 E 0.10

# %%
import matplotlib.pyplot as plt 
radius=int(input("Enter the Radius:"))
Angle=int(input("Enter the Angle in Degree "))
RZ=int(input("Enter the last value of Z you want."))
step=Angle
Angle_radian=math.radians(Angle)
theta = np.linspace( 0 , Angle_radian , step )
x = radius * np.cos( theta ) 
y = radius * np.sin( theta )
for k in np.arange(0.2,RZ,0.4):
    alpha=0
    print(";START")
    print("G1 F600 Z{:.2f}".format(k))
    for i in range(0,step):
        if alpha<1: # for second coorinates to add the distance side of the cooridnates
    
            print("X {:.2f} Y {:.2f}".format(x[i],y[i]))
            alpha+=1
        else:
            distance=sqrt((x[i]-x[i-1])**2 + (y[i]-y[i-1])**2)
            print("X {:.2f} Y {:.2f} E {:.2f}".format(x[i],y[i],distance))
    

    print(";REVERSE")
    print("G1 F600 Z{:.2f}".format(k+0.2))
#f.close
    beta=0
    for j in range(step-1,-1,-1):
        if beta<1: # for second coorinates to add the distance side of the cooridnates
    
            print("X {:.2f} Y {:.2f}".format(x[j],y[j]))
            beta+=1
        else:
            distance=sqrt((x[j]-x[j+1])**2 + (y[j]-y[j+1])**2)
            print("X {:.2f} Y {:.2f} E {:.2f}".format(x[j],y[j],distance))    
    

#If want to see the circle ( for visualization) 
#figure, axes = plt.subplots( 1 ) 
#axes.plot( x, y ) 
#axes.set_aspect( 1 ) 

# Sucessfully added in forward and reversed list with Z also.
# Out:
# Enter the Radius:10
# Enter the Angle in Degree 20
# Enter the last value of Z you want.2
# ;START
# G1 F600 Z0.20
# X 10.00 Y 0.00
# X 10.00 Y 0.18 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.46 Y 3.25 E 0.18
# X 9.40 Y 3.42 E 0.18
# ;REVERSE
# G1 F600 Z0.40
# X 9.40 Y 3.42
# X 9.46 Y 3.25 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 10.00 Y 0.18 E 0.18
# X 10.00 Y 0.00 E 0.18
# ;START
# G1 F600 Z0.60
# X 10.00 Y 0.00
# X 10.00 Y 0.18 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.46 Y 3.25 E 0.18
# X 9.40 Y 3.42 E 0.18
# ;REVERSE
# G1 F600 Z0.80
# X 9.40 Y 3.42
# X 9.46 Y 3.25 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 10.00 Y 0.18 E 0.18
# X 10.00 Y 0.00 E 0.18
# ;START
# G1 F600 Z1.00
# X 10.00 Y 0.00
# X 10.00 Y 0.18 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.46 Y 3.25 E 0.18
# X 9.40 Y 3.42 E 0.18
# ;REVERSE
# G1 F600 Z1.20
# X 9.40 Y 3.42
# X 9.46 Y 3.25 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 10.00 Y 0.18 E 0.18
# X 10.00 Y 0.00 E 0.18
# ;START
# G1 F600 Z1.40
# X 10.00 Y 0.00
# X 10.00 Y 0.18 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.46 Y 3.25 E 0.18
# X 9.40 Y 3.42 E 0.18
# ;REVERSE
# G1 F600 Z1.60
# X 9.40 Y 3.42
# X 9.46 Y 3.25 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 10.00 Y 0.18 E 0.18
# X 10.00 Y 0.00 E 0.18
# ;START
# G1 F600 Z1.80
# X 10.00 Y 0.00
# X 10.00 Y 0.18 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.46 Y 3.25 E 0.18
# X 9.40 Y 3.42 E 0.18
# ;REVERSE
# G1 F600 Z2.00
# X 9.40 Y 3.42
# X 9.46 Y 3.25 E 0.18
# X 9.52 Y 3.07 E 0.18
# X 9.57 Y 2.90 E 0.18
# X 9.62 Y 2.72 E 0.18
# X 9.67 Y 2.54 E 0.18
# X 9.72 Y 2.37 E 0.18
# X 9.76 Y 2.19 E 0.18
# X 9.80 Y 2.01 E 0.18
# X 9.83 Y 1.83 E 0.18
# X 9.86 Y 1.65 E 0.18
# X 9.89 Y 1.46 E 0.18
# X 9.92 Y 1.28 E 0.18
# X 9.94 Y 1.10 E 0.18
# X 9.96 Y 0.92 E 0.18
# X 9.97 Y 0.73 E 0.18
# X 9.98 Y 0.55 E 0.18
# X 9.99 Y 0.37 E 0.18
# X 10.00 Y 0.18 E 0.18
# X 10.00 Y 0.00 E 0.18

# %%
# Adding Writing file feature in The Final Code.

# %%
import math
import numpy as np
from math import *
import matplotlib.pyplot as plt 
radius=int(input("Enter the Radius:"))
Angle=int(input("Enter the Angle in Degree "))
RZ=int(input("Enter the last value of Z you want."))
step=Angle
Angle_radian=math.radians(Angle)
theta = np.linspace( 0 , Angle_radian , step )
x = radius * np.cos( theta ) 
y = radius * np.sin( theta )
for k in np.arange(0.2,RZ,0.4):
    alpha=0
    f = open("coordinates.txt", "a")
    f.write("\n")
    f.write(";START")
    f.write("\n")
    f.write("G1 F600 Z{:.2f}".format(k))
    f.close
    
    
    
    #print(";START")
    #print("G1 F600 Z{:.2f}".format(k))
    for i in range(0,step):
        if alpha<1: # for second coorinates to add the distance side of the cooridnates
            f = open("coordinates.txt", "a")
            f.write("\n")    
            f.write("G1 X{:.2f} Y{:.2f}".format(x[i]+160,y[i]+160))
            f.close
            alpha+=1
        else:
            distance=sqrt((x[i]-x[i-1])**2 + (y[i]-y[i-1])**2)
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f} E{:.2f}".format(x[i]+160,y[i]+160,distance))
            f.close
    
    f = open("coordinates.txt", "a")
    f.write("\n")
    f.write(";REVERSE")
    f.write("\n")
    f.write("G1 F600 Z{:.2f}".format(k+0.2))
    f.close
    #print(";REVERSE")
    #print("G1 F600 Z{:.2f}".format(k+0.2))
#f.close
    beta=0
    for j in range(step-1,-1,-1):
        if beta<1: # for second coorinates to add the distance side of the cooridnates
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f}".format(x[j]+160,y[j]+160))
            f.close
            beta+=1
        else:
            distance=sqrt((x[j]-x[j+1])**2 + (y[j]-y[j+1])**2)
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f} E{:.2f}".format(x[j]+160,y[j]+160,distance))    
            f.close
    

#If want to see the circle ( for visualization) 
#figure, axes = plt.subplots( 1 ) 
#axes.plot( x, y ) 
#axes.set_aspect( 1 ) 

# Sucessfully added in forward and reversed list with Z also.
# Out:
# Enter the Radius:15
# Enter the Angle in Degree 120
# Enter the last value of Z you want.20

# %%
# best working for odd value of Z
import math
import numpy as np
from math import *
import matplotlib.pyplot as plt 
radius=int(input("Enter the Radius:"))
Angle=int(input("Enter the Angle in Degree "))
RZ=int(input("Enter the last value of Z you want."))
step=Angle
Angle_radian=math.radians(Angle)
theta = np.linspace( 0 , Angle_radian , step )
x = radius * np.cos( theta ) 
y = radius * np.sin( theta )
for k in np.arange(0.15,RZ,0.3):
    alpha=0
    f = open("coordinates.txt", "a")
    f.write("\n")
    f.write(";START")
    f.write("\n")
    f.write("G1 F600 Z{:.2f}".format(k))
    f.close
    
    
    
    #print(";START")
    #print("G1 F600 Z{:.2f}".format(k))
    for i in range(0,step):
        if alpha<1: # for second coorinates to add the distance side of the cooridnates
            f = open("coordinates.txt", "a")
            f.write("\n")    
            f.write("G1 X{:.2f} Y{:.2f}".format(x[i]+160,y[i]+160))
            f.close
            alpha+=1
        else:
            distance=sqrt((x[i]-x[i-1])**2 + (y[i]-y[i-1])**2)
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f} E{:.2f}".format(x[i]+160,y[i]+160,distance))
            f.close
    
    f = open("coordinates.txt", "a")
    f.write("\n")
    f.write(";REVERSE")
    f.write("\n")
    f.write("G1 F600 Z{:.2f}".format(k+0.15))
    f.close
    #print(";REVERSE")
    #print("G1 F600 Z{:.2f}".format(k+0.2))
#f.close
    beta=0
    for j in range(step-1,-1,-1):
        if beta<1: # for second coorinates to add the distance side of the cooridnates
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f}".format(x[j]+160,y[j]+160))
            f.close
            beta+=1
        else:
            distance=sqrt((x[j]-x[j+1])**2 + (y[j]-y[j+1])**2)
            f = open("coordinates.txt", "a")
            f.write("\n")
            f.write("G1 X{:.2f} Y{:.2f} E{:.2f}".format(x[j]+160,y[j]+160,distance))    
            f.close
    

#If want to see the circle ( for visualization) 
#figure, axes = plt.subplots( 1 ) 
#axes.plot( x, y ) 
#axes.set_aspect( 1 ) 

# Sucessfully added in forward and reversed list with Z also.
# Out:
# Enter the Radius:15
# Enter the Angle in Degree 120
# Enter the last value of Z you want.21
